# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/MachineLearningAll/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Creation of Dataframes using pandas!**

# %%
import numpy as np
import pandas as pd

# %%
#Creating our own dataframe
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"])

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
#accesing the index
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#accesing the columns
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
#we can also make index non numeric
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"],index=["x","y","z"])

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
#for info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
#statitical info about the data
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
#unique values
df["A"].unique()
# Out:
# array([1, 4, 7])

# %%
#for the shape of our dataframe
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df=pd.read_csv("/content/coffee.csv")

# %%
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df.sample(5)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 10   Saturday    Espresso          45
# 3     Tuesday       Latte          20
# 9      Friday       Latte          35
# 5   Wednesday       Latte          25

# %%
df.iloc[0:3,[0,2]]
# Out:
#    A  C
# x  1  3
# y  4  6
# z  7  9

# %%
df.loc[1:3,"Units Sold"]=10

# %%
df.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          35

# %%
df.iat[0,0]
# Out:
# 'Monday'

# %%
df.iloc[0,0]
# Out:
# 'Monday'

# %%
df["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
df.sort_values(["Units Sold","Coffee Type"],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
for index,row in df.iterrows():
  print(row["Coffee Type"])
# Out:
# Espresso
# Latte
# Espresso
# Latte
# Espresso
# Latte
# Espresso
# Latte
# Espresso
# Latte
# Espresso
# Latte
# Espresso
# Latte
